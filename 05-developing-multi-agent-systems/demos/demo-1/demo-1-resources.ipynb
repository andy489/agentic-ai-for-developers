# %% [markdown]
# # Module 1 — Resources & Links
# **Understanding Fundamental Concepts of Multi-agent Systems**

# %%
from IPython.display import HTML, display

def section(title, icon, links):
    items = ''.join(
        f'<li style="margin:8px 0">'
        f'<a href="{url}" target="_blank" style="color:#0066cc;text-decoration:none;font-size:14px">'
        f'<span style="margin-right:6px">&#x1F517;</span>{label}</a></li>'
        for label, url in links
    )
    display(HTML(f'''
    <div style="font-family:sans-serif;margin:16px 0;border-left:4px solid #0066cc;
                padding:12px 20px;background:#f0f6ff;border-radius:0 8px 8px 0">
      <h3 style="margin:0 0 10px;color:#003d7a;font-size:16px">{icon}&nbsp;{title}</h3>
      <ul style="list-style:none;margin:0;padding:0">{items}</ul>
    </div>
    '''))

display(HTML('''
<div style="font-family:sans-serif;background:linear-gradient(135deg,#003d7a,#0066cc);
            color:white;padding:28px 32px;border-radius:12px;margin-bottom:8px">
  <h1 style="margin:0 0 6px;font-size:26px">&#x1F9E0; Module 1 Resources</h1>
  <p style="margin:0;opacity:0.85;font-size:14px">Understanding Fundamental Concepts of Multi-agent Systems</p>
</div>
'''))

section('Courses & Learning', '&#x1F4DA;', [
    ('Introduction to Developing AI Agents', 'https://pluralsight.com/library/courses/introduction-developing-ai-agents/'),
    ('Whitepaper Agent Companion', 'https://www.kaggle.com/whitepaper-agent-companion'),
])

section('LangGraph', '&#x1F9F1;', [
    ('Multi-agent systems — LangGraph Concepts', 'https://langchain-ai.github.io/langgraph/concepts/multi_agent/'),
    ('LangGraph Graph API Concepts', 'https://langchain-ai.github.io/langgraph/concepts/low_level/'),
    ('Why LangGraph', 'https://langchain-ai.github.io/langgraph/concepts/why-langgraph/'),
    ('Human-in-the-loop', 'https://langchain-ai.github.io/langgraph/agents/human-in-the-loop/'),
    ('LangGraph Structured Output', 'https://langchain-ai.github.io/langgraph/concepts/agentic_concepts/#structured-output'),
    ('LangGraph Community Agents', 'https://langchain-ai.github.io/langgraph/agents/prebuilt/'),
    ('Get started with LangSmith', 'https://docs.smith.langchain.com/'),
])

section('Agent Protocols & Standards', '&#x1F4E1;', [
    ('Announcing the Agent2Agent Protocol (A2A)', 'https://developers.googleblog.com/en/a2a-a-new-era-of-agent-interoperability/'),
    ('Agent2Agent (A2A) Protocol — GitHub', 'https://github.com/google/A2A'),
    ('Introducing the Model Context Protocol', 'https://www.anthropic.com/news/model-context-protocol'),
    ('MCP Documentation', 'https://modelcontextprotocol.io/introduction'),
])

section('Models & APIs', '&#x26A1;', [
    ('Introducing GPT-4.1 in the API', 'https://openai.com/index/gpt-4-1/'),
    ('GPT-4.1 Prompting Guide', 'https://cookbook.openai.com/examples/gpt4-1_prompting_guide'),
])

section('Tools & Integrations', '&#x1F6E0;', [
    ('Dall-E Image Generator (LangChain)', 'https://python.langchain.com/docs/integrations/tools/dalle_image_generator/'),
    ('Contract Net Protocol', 'https://en.wikipedia.org/wiki/Contract_Net_Protocol'),
])
# Out:
# <div style="font-family:sans-serif;background:linear-gradient(135deg,#003d7a,#0066cc);
#             color:white;padding:28px 32px;border-radius:12px;margin-bottom:8px">
#   <h1 style="margin:0 0 6px;font-size:26px">&#x1F9E0; Module 1 Resources</h1>
#   <p style="margin:0;opacity:0.85;font-size:14px">Understanding Fundamental Concepts of Multi-agent Systems</p>
# </div>
#     <div style="font-family:sans-serif;margin:16px 0;border-left:4px solid #0066cc;
#                 padding:12px 20px;background:#f0f6ff;border-radius:0 8px 8px 0">
#       <h3 style="margin:0 0 10px;color:#003d7a;font-size:16px">&#x1F4DA;&nbsp;Courses & Learning</h3>
# ...

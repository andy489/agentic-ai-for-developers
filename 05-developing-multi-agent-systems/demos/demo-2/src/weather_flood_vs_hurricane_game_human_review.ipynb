# %%
import importlib.util, subprocess, sys

_pkgs = ["langgraph", "langchain_community", "langchain_openai", "langsmith", "langgraph-supervisor"]
_missing = [p for p in _pkgs if importlib.util.find_spec(p.replace("-", "_").split("[")[0]) is None]
if _missing:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q"] + _pkgs)
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Environment Variable Initialization

import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())  # loads .env from the notebook's working directory

def _set_if_undefined(var_name: str):
    value = os.environ.get(var_name, "").strip()
    if value:
        masked = value[:6] + "*" * (min(20, len(value) - 6))
        print(f"  ✅ {var_name}: {masked}")
    else:
        print(f"  ❌ {var_name}: not set")

# ---- Environment Variables Required ----

print("Checking environment variables...")
_set_if_undefined("OPENAI_API_KEY")         # API key for OpenAI models
_set_if_undefined("LANGSMITH_TRACING")      # Enable LangSmith tracing ("true" to enable)
_set_if_undefined("LANGSMITH_API_KEY")      # https://docs.langchain.com/langsmith/observability
_set_if_undefined("OPENAI_MODEL")           # e.g., "gpt-4.1", "gpt-4o", "gpt-4o-mini"
print("Done.")
# Out:
# Checking environment variables...
#   ✅ OPENAI_API_KEY: sk-pro********************
#   ✅ LANGSMITH_TRACING: true
#   ✅ LANGSMITH_API_KEY: lsv2_p********************
#   ✅ OPENAI_MODEL: gpt-4o*****
# Done.

# %%
# Auctions game theory 
# - Two agents (bidder1 and bidder2) bid for tasks based on their capabilities. 
# - Each agent shares their strengths using a player card. 
# - auctioneer decides which agent gets the task. 


# ---- Imports ----

import os
import time
import random
import json
import warnings
from langchain_openai import ChatOpenAI
from typing import Literal, Annotated
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage, SystemMessage
from langgraph.types import Command, interrupt
from langgraph.graph import StateGraph,MessagesState, START, END
from langgraph.prebuilt import create_react_agent
from langgraph.warnings import LangGraphDeprecatedSinceV10
from langchain_core.tools import tool
from pydantic import BaseModel
from pprint import pprint
from langchain_core.globals import set_debug

# Silence the create_react_agent V1.0 deprecation warning so demo output is clean.
warnings.filterwarnings("ignore", category=LangGraphDeprecatedSinceV10)

set_debug(False)
# ---- LLM Setup ----

# Load the default model from environment variables
openai_model = os.environ["OPENAI_MODEL"]
# Initialize the LLM (Large Language Model) interface
llm = ChatOpenAI(model=openai_model)

class OverallState(MessagesState):
    """State to track bidder's work."""
    
    selected_bidder_for_flood_report: Annotated[str, "selected player or bidder to generate report on flood based on the provided weather data"]
    selected_bidder_for_hurricane_report : Annotated[str, "selected player or bidder to generate report on hurricane based on the provided weather data"]
    final_report: Annotated[str, "final consolidated report generated by the auctioneer"]
    step: Annotated[int, "current step in the auction process"]
    weather_data : Annotated[str, "weather data provided as input"]
    feedback : Annotated[str, "human feedback on the final report"]

# Define a dummy luggage_support_tool
@tool
def get_player_card_tool(agent_name: Annotated[str, "name of the agent or player who is requesting their playercard."]):
    """Tool to fetch player card information for a given agent or player name."""
    
    player_cards = {
        "bidder1": {"flood_knowledge": random.randint(5, 8), "hurricane_knowledge": random.randint(3, 8), "response_time": random.randint(0, 3)},
        "bidder2": {"flood_knowledge": random.randint(3, 7), "hurricane_knowledge": random.randint(2, 9), "response_time": random.randint(0, 3)}
    }
    return player_cards.get(agent_name, {"error": "unknown player"})

class selected_bidders(BaseModel):
    """class to store the selected agents or players for flood and hurrican report generation."""
    selected_bidder_for_flood_report:  Annotated[str, "selected player or bidder to generate report on flood based on the provided weather data"]
    selected_bidder_for_hurricane_report:  Annotated[str, "selected player or bidder to generate report on hurricane based on the provided weather data"]
    selection_reasoning:  Annotated[str, "reason to choose a player or bidder for the task"]


class player_card(BaseModel):
    """class to store player or agents data."""
    player_name: Annotated[str, "name of the player or agent"]
    flood_knowledge_out_of_10 : Annotated[int, "flood knowledge out of 10"]
    hurricane_knowledge_out_of_10 : Annotated[int, "hurricane knowledge out of 10"]
    response_time_in_seconds: Annotated[int, "response time in seconds"] 

# Creating a generalized agent creation function to reduce redundancy
def create_bidder_player_card_agent(agent_name: str):
    """Creates a React agent for the bidder."""
    return create_react_agent(
        llm,  
        tools=[get_player_card_tool],  
        prompt=f"You are a helpful agent, your name is {agent_name}. Your task is to get the player card data for yourself. You can use tools to get the data. ",
        response_format=player_card
    )

def create_prompt(input: MessagesState):
    return ("Based on the following data, choose the most suitable bidder to generate reports for flood and hurricane events. "
            "- Prioritize the knowledge of each bidder in the relevant subject (flood or hurricane) over their response time. "
            "- Response time should only be considered if two bidders have similar levels of expertise. "
            "- If bidders have identical knowledge levels, select the bidder with the shorter response time. "
            "- If bidders have the exact same knowledge and response time, you may randomly choose between them. "
            "- Provide a detailed explanation for your choice, including the reasons behind your decision-making process. "
            f"Here is the data: {input}")

get_selected_bidders = create_react_agent(
    llm,  
    tools=[],  
    prompt=create_prompt, 
    response_format=selected_bidders
)

# Function to handle bidding process and generating responses
def handle_bidder_steps(agent_name: str, state: OverallState, step: str):
    """Handles the bidder's steps and actions based on the state."""
    
    if step == "step-1":
      
        response = create_bidder_player_card_agent(agent_name).invoke(state)
        player_card_data = response["structured_response"]
    
        return Command(
            goto=["auctioneer"],
            update={
                "messages": [
                    HumanMessage(content=f"{agent_name} response time in seconds : {player_card_data.response_time_in_seconds}", name=agent_name),
                    HumanMessage(content=f"{agent_name} flood knowledge out of 10 : {player_card_data.flood_knowledge_out_of_10}", name=agent_name),
                    HumanMessage(content=f"{agent_name} hurricane knowledge out of 10 : {player_card_data.hurricane_knowledge_out_of_10}", name=agent_name),
                    HumanMessage(content=f"{agent_name} shared the player card data", name=agent_name)
                ]
            }
        )
    
    if step == "step-2":

        for_flood = state["selected_bidder_for_flood_report"]
        for_hurricane = state["selected_bidder_for_hurricane_report"]
        
        if agent_name in (for_flood, for_hurricane):
          
            messages = [f" based on the following data generate a report on the given topic(s). Here is the data: {state["weather_data"]} "]
            
            topics = []
            if agent_name == for_flood:
                topics.append("flood")
            if agent_name == for_hurricane:
                topics.append("hurricane")
            if topics:
                messages += " Topics: " + ", ".join(topics)

            report = llm.invoke(messages)

            return Command(
                goto=["auctioneer"],
                update={
                    "messages": [
                        HumanMessage(content=f"{agent_name} generated report(s) : {report.content} ", name=agent_name)
                    ]
                }
            )
        

        return Command(goto=["auctioneer"])
    
    
    return Command(
        goto=["auctioneer"],
        update={
            "messages": [
                HumanMessage(content=f"{agent_name} Unknown step", name=agent_name)
            ]
        }
    )
    

def bidder1(state: OverallState) -> Command[Literal["auctioneer"]]:
    """
    You are bidder1. 
    """
   
    step = state["messages"][-1].content
    return handle_bidder_steps("bidder1", state, step)
    

def bidder2(state: OverallState) -> Command[Literal["auctioneer"]]:
    """
    You are bidder2. 
    """
   
    step = state["messages"][-1].content
    return handle_bidder_steps("bidder2", state, step)
    

def human_review_node(state: OverallState) -> Command[Literal["auctioneer"]]:
    """
    Interrupt the flow to request human feedback on the report.
    Possible human actions: feedback, publish, update, delete.
    """
    human_review = interrupt({
        "ask": (
            "Please provide feedback (example: {'action': 'feedback', 'data': 'reduce size'}) "
            "Possible actions: [feedback, publish]"
        ),
        "report_to_review": state["final_report"]
    })

    review_action = human_review["action"]
    review_data = human_review["data"]

    if review_action == "publish":
        return Command(goto="auctioneer")
    
    if review_action == "feedback":
        return Command(goto="auctioneer", update={"feedback": review_data})
   
    return Command(goto="auctioneer")

def auctioneer(state: OverallState) -> Command[Literal["bidder1", "bidder2", "human_review_node",END]]:
    """
    initiate the gameplay
    """

    if(state["step"] == 1):
       
        next_step = state["step"] + 1

        return Command(
            goto=["bidder1", "bidder2"],
            update={
                "messages": [
                    HumanMessage(content=f"Share your player card data", name="auctioneer"),
                    HumanMessage(content=f"step-1", name="auctioneer")
                ],
                "step" : next_step}) 
   
    elif(state["step"] == 2):
       
        next_step = state["step"] + 1

        response = get_selected_bidders.invoke(state)
        selected_bidders_data = response["structured_response"]

        pprint(selected_bidders_data)

        return Command(
            goto=["bidder1", "bidder2"],
            update={
                "messages": [
                    HumanMessage(content=f"Selected bidder for the flood reporting : {selected_bidders_data.selected_bidder_for_flood_report}", name="auctioneer"),
                    HumanMessage(content=f"Selected bidder for the hurricane reporting : {selected_bidders_data.selected_bidder_for_hurricane_report}", name="auctioneer"),
                    HumanMessage(content=f"Selection reasoning : {selected_bidders_data.selection_reasoning}", name="auctioneer"),
                    HumanMessage(content="step-2", name="auctioneer")
                ],
                "selected_bidder_for_flood_report" : selected_bidders_data.selected_bidder_for_flood_report,
                "selected_bidder_for_hurricane_report" : selected_bidders_data.selected_bidder_for_hurricane_report,
                "step" : next_step}) 

    elif(state["step"] == 3):
       
        next_step = state["step"] + 1

        messages = (" Based on the message history, generate a final consolidated weather report on flood and hurricane. "
                    " Here is the message history: "
                    f"{state["messages"]}")
        
        final_report = llm.invoke(messages)

        return Command(
            goto=["human_review_node"],
            update={
                "messages": [
                    HumanMessage(content=f"Final report: {final_report.content}", name="auctioneer")
                ],
                "final_report" : final_report.content,
                "step" : next_step
            })

    elif(state["step"] == 4):
               
        messages = (" Based on the following feedback, improve the weather report. If there is no feedback then return the report as it is. "
                    f"Human feeback: : {state["feedback"]} "
                    f"Original report: {state["final_report"]} ")
        
        final_report = llm.invoke(messages)

        return Command(
            goto=[END],
            update={
                "messages": [
                    HumanMessage(content=f"Final report: {final_report.content}", name="auctioneer")
                ],
                "final_report" : final_report.content
            })  
    
    else:
        return Command(goto=[END])

# %%
# Build the state graph
graph_builder = StateGraph(OverallState)
graph_builder.add_node("auctioneer", auctioneer)
graph_builder.add_node("bidder1", bidder1)
graph_builder.add_node("bidder2", bidder2)
graph_builder.add_node("human_review_node", human_review_node)

# Define start 
graph_builder.add_edge(START, "auctioneer")

# Use MemorySaver as checkpointer (required for human interrupt/resume)
checkpointer = MemorySaver()

# Compile the graph
graph = graph_builder.compile(checkpointer=checkpointer)

# %%
from IPython.display import display, Image

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
import uuid

# Assign a thread ID for the session
thread_config = {"configurable": {"thread_id": uuid.uuid4()}}

def get_weather_data():
    # Mock weather data for hurricane and flood
   
    weather_data = (" Hurricane data: "
                    "   Task Type: hurricane " 
                    "   Data: This includes information such as: " 
                    "       Storm Name: Hurricane Ida " 
                    "       Category: 4 " 
                    "       Wind Speed: 145 mph " 
                    "       Coordinates: Latitude: 25.5, Longitude: -81.5 " 
                    "       Forecast: Expected landfall date, affected areas (Florida, Georgia, South Carolina), and warnings for evacuation orders. " 
                    " Flood data: " 
                    "   Task Type: Flood " 
                    "   Data: This includes information such as: " 
                    "       Flood Warning: True " 
                    "       Affected Regions: Southern Texas, Louisiana " 
                    "       Rainfall Data: 24-hour rainfall (10.5 inches), total rainfall over the last 72 hours (30.1 inches) " 
                    "       River Levels: Mississippi River, with current level and flood stage details. " 
                    "       Forecast: Expected peak river level (36.0 feet) and evacuation orders. " )
    return weather_data


weather_data = get_weather_data()

for s in graph.stream(
    {"messages": [("user", " Find best agent or bidder for the tasks. ")],
     "step": 1,
     "weather_data" : weather_data}, 
     config=thread_config):
    pprint(s)
    pprint("============================")


# Resume: Human gives feedback to "add emojis"
for s in graph.stream(
    Command(resume={"action": "feedback", "data": "add emojis to the report"}),
    config=thread_config
):
    pprint(s)
    pprint("============================")
# Out:
# {'auctioneer': {'messages': [HumanMessage(content='Share your player card data', additional_kwargs={}, response_metadata={}, name='auctioneer', id='ab3b03b8-9c35-4e33-86de-c91dc874cf77'),
#                              HumanMessage(content='step-1', additional_kwargs={}, response_metadata={}, name='auctioneer', id='b364d689-a01e-440b-a002-73e8ce32d3f5')],
#                 'step': 2}}
# '============================'
# {'bidder1': {'messages': [HumanMessage(content='bidder1 response time in seconds : 1', additional_kwargs={}, response_metadata={}, name='bidder1'),
#                           HumanMessage(content='bidder1 flood knowledge out of 10 : 5', additional_kwargs={}, response_metadata={}, name='bidder1'),
#                           HumanMessage(content='bidder1 hurricane knowledge out of 10 : 8', additional_kwargs={}, response_metadata={}, name='bidder1'),
#                           HumanMessage(content='bidder1 shared the player card data', additional_kwargs={}, response_metadata={}, name='bidder1')]}}
# '============================'
# {'bidder2': {'messages': [HumanMessage(content='bidder2 response time in seconds : 0', additional_kwargs={}, response_metadata={}, name='bidder2'),
#                           HumanMessage(content='bidder2 flood knowledge out of 10 : 5', additional_kwargs={}, response_metadata={}, name='bidder2'),
#                           HumanMessage(content='bidder2 hurricane knowledge out of 10 : 4', additional_kwargs={}, response_metadata={}, name='bidder2'),
#                           HumanMessage(content='bidder2 shared the player card data', additional_kwargs={}, response_metadata={}, name='bidder2')]}}
# '============================'
# selected_bidders(selected_bidder_for_flood_report='bidder1', selected_bidder_for_hurricane_report='bidder1', selection_reasoning='Bidder 1 has superior hurricane knowledge (8/10) compared to Bidder 2 (4/10), making them the preferred choice for both flood and hurricane report generation despite similar flood knowledge (5/10) between the two bidders.')
# {'auctioneer': {'messages': [HumanMessage(content='Selected bidder for the flood reporting : bidder1', additional_kwargs={}, response_metadata={}, name='auctioneer', id='1c0b175e-e64d-47de-8101-e109b5951ded'),
#                              HumanMessage(content='Selected bidder for the hurricane reporting : bidder1', additional_kwargs={}, response_metadata={}, name='auctioneer', id='06b34d81-9d8f-4116-b901-c7096886c100'),
#                              HumanMessage(content='Selection reasoning : Bidder 1 has superior hurricane knowledge (8/10) compared to Bidder 2 (4/10), making them the preferred choice for both flood and hurricane report generation despite similar flood knowledge (5/10) between the two bidders.', additional_kwargs={}, response_metadata={}, name='auctioneer', id='6e707ac4-6d7c-45a3-8a87-585258fd89a8'),
#                              HumanMessage(content='step-2', additional_kwargs={}, response_metadata={}, name='auctioneer', id='f8329ec0-890d-45b0-b179-68b4c3c677d9')],
#                 'selected_bidder_for_flood_report': 'bidder1',
#                 'selected_bidder_for_hurricane_report': 'bidder1',
#                 'step': 3}}
# '============================'
# {'bidder2': None}
# '============================'
# {'bidder1': {'messages': [HumanMessage(content='bidder1 generated report(s) : ### Report on Recent Natural Disasters: Hurricane Ida and Flooding in Southern Texas and Louisiana\n\n#### Overview\nThis report summarizes the current situation regarding Hurricane Ida and significant flooding incidents affecting Southern Texas and Louisiana. The data reflects the severity and potential impact of these natural disasters on nearby populations and infrastructure.\n\n---\n\n#### Hurricane Ida\n\n**Storm Details:**\n- **Storm Name:** Hurricane Ida\n- **Category:** 4\n- **Wind Speed:** 145 mph\n- **Coordinates:** Latitude: 25.5, Longitude: -81.5\n\n**Impact Forecast:**\nHurricane Ida is a powerful Category 4 storm, posing a significant threat due to its high wind speeds. It is anticipated to make landfall soon, affecting various regions, specifically:\n- **Affected Areas:** Florida, Georgia, South Carolina\n\n**Evacuation Orders:**\nAuthorities are issuing warnings for evacuation orders in the anticipated impact zones to ensure the safety of residents. Specific evacuation procedures and routes will be provided by local emergency services.\n\n---\n\n#### Flooding in Southern Texas and Louisiana\n\n**Flood Details:**\n- **Flood Warning:** Active\n- **Affected Regions:** Southern Texas, Louisiana\n\n**Rainfall Data:**\n- **24-hour Rainfall:** 10.5 inches\n- **Total Rainfall Over Last 72 Hours:** 30.1 inches\n\nGiven the substantial rainfall, there is an ongoing risk of severe flooding in affected areas, necessitating immediate attention from local disaster management teams.\n\n**River Levels:**\n- **River:** Mississippi River\n- **Current Level:** [Data not provided; requires current status]\n- **Flood Stage:** [Data not provided; requires flood stage reference]\n\n**Forecast:**\nThe expected peak river level is projected to reach **36.0 feet**, which demands urgent response efforts and potential evacuation orders. \n\n---\n\n#### Conclusion\nThe dual threats of Hurricane Ida and flooding in Southern Texas and Louisiana present a critical situation requiring swift response and coordination among state and federal agencies. Residents in the affected areas are urged to stay informed through local weather reports and follow the guidance of emergency management officials to ensure their safety. The combination of high winds from the hurricane and unprecedented rainfall leading to flooding underscores the need for heightened preparedness and community support in these challenging times. \n\n--- \n\n#### Recommendations\n1. **Regular Updates:** Establish a communication system for real-time updates regarding both climate phenomena.\n2. **Evacuation Drills:** Conduct drills to prepare residents in vulnerable regions for potential evacuations.\n3. **Flood Preparedness:** Equip communities with resources for flood safety and recovery efforts.\n4. **Monitoring:** Ensure constant monitoring of river levels and weather forecasts to provide timely warnings. ', additional_kwargs={}, response_metadata={}, name='bidder1')]}}
# '============================'
# {'auctioneer': {'final_report': '**Final Weather Report on Flood and '
#                                 'Hurricane**\n'
#                                 '\n'
#                                 '### Report on Recent Natural Disasters: '
#                                 'Hurricane Ida and Flooding in Southern Texas '
#                                 'and Louisiana\n'
#                                 '\n'
#                                 '#### Overview\n'
#                                 'This report summarizes the current situation '
#                                 'regarding Hurricane Ida and significant '
#                                 'flooding incidents affecting Southern Texas '
#                                 'and Louisiana. The data reflects the severity '
#                                 'and potential impact of these natural '
#                                 'disasters on nearby populations and '
#                                 'infrastructure.\n'
#                                 '\n'
#                                 '---\n'
#                                 '\n'
#                                 '#### Hurricane Ida\n'
#                                 '\n'
#                                 '**Storm Details:**\n'
#                                 '- **Storm Name:** Hurricane Ida\n'
#                                 '- **Category:** 4\n'
#                                 '- **Wind Speed:** 145 mph\n'
#                                 '- **Coordinates:** Latitude: 25.5, Longitude: '
#                                 '-81.5\n'
#                                 '\n'
#                                 '**Impact Forecast:**\n'
#                                 'Hurricane Ida is a powerful Category 4 storm, '
#                                 'posing a significant threat due to its high '
#                                 'wind speeds. It is anticipated to make '
#                                 'landfall soon, affecting various regions, '
#                                 'specifically:\n'
#                                 '- **Affected Areas:** Florida, Georgia, South '
#                                 'Carolina\n'
#                                 '\n'
#                                 '**Evacuation Orders:**\n'
#                                 'Authorities are issuing warnings for '
#                                 'evacuation orders in the anticipated impact '
#                                 'zones to ensure the safety of residents. '
#                                 'Specific evacuation procedures and routes '
#                                 'will be provided by local emergency '
#                                 'services.\n'
#                                 '\n'
#                                 '---\n'
#                                 '\n'
#                                 '#### Flooding in Southern Texas and '
#                                 'Louisiana\n'
#                                 '\n'
#                                 '**Flood Details:**\n'
#                                 '- **Flood Warning:** Active\n'
#                                 '- **Affected Regions:** Southern Texas, '
#                                 'Louisiana\n'
#                                 '\n'
#                                 '**Rainfall Data:**\n'
#                                 '- **24-hour Rainfall:** 10.5 inches\n'
#                                 '- **Total Rainfall Over Last 72 Hours:** 30.1 '
#                                 'inches\n'
#                                 '\n'
#                                 'Given the substantial rainfall, there is an '
#                                 'ongoing risk of severe flooding in affected '
#                                 'areas, necessitating immediate attention from '
#                                 'local disaster management teams.\n'
#                                 '\n'
#                                 '**River Levels:**\n'
#                                 '- **River:** Mississippi River\n'
#                                 '- **Current Level:** [Data not provided; '
#                                 'requires current status]\n'
#                                 '- **Flood Stage:** [Data not provided; '
#                                 'requires flood stage reference]\n'
#                                 '\n'
#                                 '**Forecast:**\n'
#                                 'The expected peak river level is projected to '
#                                 'reach **36.0 feet**, which demands urgent '
#                                 'response efforts and potential evacuation '
#                                 'orders. \n'
#                                 '\n'
#                                 '---\n'
#                                 '\n'
#                                 '#### Conclusion\n'
#                                 'The dual threats of Hurricane Ida and '
#                                 'flooding in Southern Texas and Louisiana '
#                                 'present a critical situation requiring swift '
#                                 'response and coordination among state and '
#                                 'federal agencies. Residents in the affected '
#                                 'areas are urged to stay informed through '
#                                 'local weather reports and follow the guidance '
#                                 'of emergency management officials to ensure '
#                                 'their safety. The combination of high winds '
#                                 'from the hurricane and unprecedented rainfall '
#                                 'leading to flooding underscores the need for '
#                                 'heightened preparedness and community support '
#                                 'in these challenging times.\n'
#                                 '\n'
#                                 '---\n'
#                                 '\n'
#                                 '#### Recommendations\n'
#                                 '1. **Regular Updates:** Establish a '
#                                 'communication system for real-time updates '
#                                 'regarding both climate phenomena.\n'
#                                 '2. **Evacuation Drills:** Conduct drills to '
#                                 'prepare residents in vulnerable regions for '
#                                 'potential evacuations.\n'
#                                 '3. **Flood Preparedness:** Equip communities '
#                                 'with resources for flood safety and recovery '
#                                 'efforts.\n'
#                                 '4. **Monitoring:** Ensure constant monitoring '
#                                 'of river levels and weather forecasts to '
#                                 'provide timely warnings. \n'
#                                 '\n'
#                                 'This report is essential for ensuring '
#                                 'community safety and preparedness during '
#                                 'these severe weather events.',
#                 'messages': [HumanMessage(content='Final report: **Final Weather Report on Flood and Hurricane**\n\n### Report on Recent Natural Disasters: Hurricane Ida and Flooding in Southern Texas and Louisiana\n\n#### Overview\nThis report summarizes the current situation regarding Hurricane Ida and significant flooding incidents affecting Southern Texas and Louisiana. The data reflects the severity and potential impact of these natural disasters on nearby populations and infrastructure.\n\n---\n\n#### Hurricane Ida\n\n**Storm Details:**\n- **Storm Name:** Hurricane Ida\n- **Category:** 4\n- **Wind Speed:** 145 mph\n- **Coordinates:** Latitude: 25.5, Longitude: -81.5\n\n**Impact Forecast:**\nHurricane Ida is a powerful Category 4 storm, posing a significant threat due to its high wind speeds. It is anticipated to make landfall soon, affecting various regions, specifically:\n- **Affected Areas:** Florida, Georgia, South Carolina\n\n**Evacuation Orders:**\nAuthorities are issuing warnings for evacuation orders in the anticipated impact zones to ensure the safety of residents. Specific evacuation procedures and routes will be provided by local emergency services.\n\n---\n\n#### Flooding in Southern Texas and Louisiana\n\n**Flood Details:**\n- **Flood Warning:** Active\n- **Affected Regions:** Southern Texas, Louisiana\n\n**Rainfall Data:**\n- **24-hour Rainfall:** 10.5 inches\n- **Total Rainfall Over Last 72 Hours:** 30.1 inches\n\nGiven the substantial rainfall, there is an ongoing risk of severe flooding in affected areas, necessitating immediate attention from local disaster management teams.\n\n**River Levels:**\n- **River:** Mississippi River\n- **Current Level:** [Data not provided; requires current status]\n- **Flood Stage:** [Data not provided; requires flood stage reference]\n\n**Forecast:**\nThe expected peak river level is projected to reach **36.0 feet**, which demands urgent response efforts and potential evacuation orders. \n\n---\n\n#### Conclusion\nThe dual threats of Hurricane Ida and flooding in Southern Texas and Louisiana present a critical situation requiring swift response and coordination among state and federal agencies. Residents in the affected areas are urged to stay informed through local weather reports and follow the guidance of emergency management officials to ensure their safety. The combination of high winds from the hurricane and unprecedented rainfall leading to flooding underscores the need for heightened preparedness and community support in these challenging times.\n\n---\n\n#### Recommendations\n1. **Regular Updates:** Establish a communication system for real-time updates regarding both climate phenomena.\n2. **Evacuation Drills:** Conduct drills to prepare residents in vulnerable regions for potential evacuations.\n3. **Flood Preparedness:** Equip communities with resources for flood safety and recovery efforts.\n4. **Monitoring:** Ensure constant monitoring of river levels and weather forecasts to provide timely warnings. \n\nThis report is essential for ensuring community safety and preparedness during these severe weather events.', additional_kwargs={}, response_metadata={}, name='auctioneer', id='c0ef0fbb-ab0a-4f05-a016-ec9e5492e0ac')],
#                 'step': 4}}
# '============================'
# {'__interrupt__': (Interrupt(value={'ask': 'Please provide feedback (example: '
#                                            "{'action': 'feedback', 'data': "
#                                            "'reduce size'}) Possible actions: "
#                                            '[feedback, publish]',
#                                     'report_to_review': '**Final Weather '
#                                                         'Report on Flood and '
#                                                         'Hurricane**\n'
#                                                         '\n'
#                                                         '### Report on Recent '
#                                                         'Natural Disasters: '
#                                                         'Hurricane Ida and '
#                                                         'Flooding in Southern '
#                                                         'Texas and Louisiana\n'
#                                                         '\n'
#                                                         '#### Overview\n'
#                                                         'This report '
#                                                         'summarizes the '
#                                                         'current situation '
#                                                         'regarding Hurricane '
#                                                         'Ida and significant '
#                                                         'flooding incidents '
#                                                         'affecting Southern '
#                                                         'Texas and Louisiana. '
#                                                         'The data reflects the '
#                                                         'severity and '
#                                                         'potential impact of '
#                                                         'these natural '
#                                                         'disasters on nearby '
#                                                         'populations and '
#                                                         'infrastructure.\n'
#                                                         '\n'
#                                                         '---\n'
#                                                         '\n'
#                                                         '#### Hurricane Ida\n'
#                                                         '\n'
#                                                         '**Storm Details:**\n'
#                                                         '- **Storm Name:** '
#                                                         'Hurricane Ida\n'
#                                                         '- **Category:** 4\n'
#                                                         '- **Wind Speed:** 145 '
#                                                         'mph\n'
#                                                         '- **Coordinates:** '
#                                                         'Latitude: 25.5, '
#                                                         'Longitude: -81.5\n'
#                                                         '\n'
#                                                         '**Impact Forecast:**\n'
#                                                         'Hurricane Ida is a '
#                                                         'powerful Category 4 '
#                                                         'storm, posing a '
#                                                         'significant threat '
#                                                         'due to its high wind '
#                                                         'speeds. It is '
#                                                         'anticipated to make '
#                                                         'landfall soon, '
#                                                         'affecting various '
#                                                         'regions, '
#                                                         'specifically:\n'
#                                                         '- **Affected Areas:** '
#                                                         'Florida, Georgia, '
#                                                         'South Carolina\n'
#                                                         '\n'
#                                                         '**Evacuation '
#                                                         'Orders:**\n'
#                                                         'Authorities are '
#                                                         'issuing warnings for '
#                                                         'evacuation orders in '
#                                                         'the anticipated '
#                                                         'impact zones to '
#                                                         'ensure the safety of '
#                                                         'residents. Specific '
#                                                         'evacuation procedures '
#                                                         'and routes will be '
#                                                         'provided by local '
#                                                         'emergency services.\n'
#                                                         '\n'
#                                                         '---\n'
#                                                         '\n'
#                                                         '#### Flooding in '
#                                                         'Southern Texas and '
#                                                         'Louisiana\n'
#                                                         '\n'
#                                                         '**Flood Details:**\n'
#                                                         '- **Flood Warning:** '
#                                                         'Active\n'
#                                                         '- **Affected '
#                                                         'Regions:** Southern '
#                                                         'Texas, Louisiana\n'
#                                                         '\n'
#                                                         '**Rainfall Data:**\n'
#                                                         '- **24-hour '
#                                                         'Rainfall:** 10.5 '
#                                                         'inches\n'
#                                                         '- **Total Rainfall '
#                                                         'Over Last 72 Hours:** '
#                                                         '30.1 inches\n'
#                                                         '\n'
#                                                         'Given the substantial '
#                                                         'rainfall, there is an '
#                                                         'ongoing risk of '
#                                                         'severe flooding in '
#                                                         'affected areas, '
#                                                         'necessitating '
#                                                         'immediate attention '
#                                                         'from local disaster '
#                                                         'management teams.\n'
#                                                         '\n'
#                                                         '**River Levels:**\n'
#                                                         '- **River:** '
#                                                         'Mississippi River\n'
#                                                         '- **Current Level:** '
#                                                         '[Data not provided; '
#                                                         'requires current '
#                                                         'status]\n'
#                                                         '- **Flood Stage:** '
#                                                         '[Data not provided; '
#                                                         'requires flood stage '
#                                                         'reference]\n'
#                                                         '\n'
#                                                         '**Forecast:**\n'
#                                                         'The expected peak '
#                                                         'river level is '
#                                                         'projected to reach '
#                                                         '**36.0 feet**, which '
#                                                         'demands urgent '
#                                                         'response efforts and '
#                                                         'potential evacuation '
#                                                         'orders. \n'
#                                                         '\n'
#                                                         '---\n'
#                                                         '\n'
#                                                         '#### Conclusion\n'
#                                                         'The dual threats of '
#                                                         'Hurricane Ida and '
#                                                         'flooding in Southern '
#                                                         'Texas and Louisiana '
#                                                         'present a critical '
#                                                         'situation requiring '
#                                                         'swift response and '
#                                                         'coordination among '
#                                                         'state and federal '
#                                                         'agencies. Residents '
#                                                         'in the affected areas '
#                                                         'are urged to stay '
#                                                         'informed through '
#                                                         'local weather reports '
#                                                         'and follow the '
#                                                         'guidance of emergency '
#                                                         'management officials '
#                                                         'to ensure their '
#                                                         'safety. The '
#                                                         'combination of high '
#                                                         'winds from the '
#                                                         'hurricane and '
#                                                         'unprecedented '
#                                                         'rainfall leading to '
#                                                         'flooding underscores '
#                                                         'the need for '
#                                                         'heightened '
#                                                         'preparedness and '
#                                                         'community support in '
#                                                         'these challenging '
#                                                         'times.\n'
#                                                         '\n'
#                                                         '---\n'
#                                                         '\n'
#                                                         '#### Recommendations\n'
#                                                         '1. **Regular '
#                                                         'Updates:** Establish '
#                                                         'a communication '
#                                                         'system for real-time '
#                                                         'updates regarding '
#                                                         'both climate '
#                                                         'phenomena.\n'
#                                                         '2. **Evacuation '
#                                                         'Drills:** Conduct '
#                                                         'drills to prepare '
#                                                         'residents in '
#                                                         'vulnerable regions '
#                                                         'for potential '
#                                                         'evacuations.\n'
#                                                         '3. **Flood '
#                                                         'Preparedness:** Equip '
#                                                         'communities with '
#                                                         'resources for flood '
#                                                         'safety and recovery '
#                                                         'efforts.\n'
#                                                         '4. **Monitoring:** '
#                                                         'Ensure constant '
#                                                         'monitoring of river '
#                                                         'levels and weather '
#                                                         'forecasts to provide '
#                                                         'timely warnings. \n'
#                                                         '\n'
#                                                         'This report is '
#                                                         'essential for '
#                                                         'ensuring community '
#                                                         'safety and '
#                                                         'preparedness during '
#                                                         'these severe weather '
#                                                         'events.'},
#                              id='aa17ad67ac9843462ebb74bbbc687f7b'),)}
# '============================'
# {'human_review_node': {'feedback': 'add emojis to the report'}}
# '============================'
# {'auctioneer': {'final_report': '**Final Weather Report on Flood and '
#                                 'Hurricane** 🌪️🌧️\n'
#                                 '\n'
#                                 '### Report on Recent Natural Disasters: '
#                                 'Hurricane Ida and Flooding in Southern Texas '
#                                 'and Louisiana\n'
#                                 '\n'
#                                 '#### Overview\n'
#                                 'This report summarizes the current situation '
#                                 'regarding Hurricane Ida and significant '
#                                 'flooding incidents affecting Southern Texas '
#                                 'and Louisiana. The data reflects the severity '
#                                 'and potential impact of these natural '
#                                 'disasters on nearby populations and '
#                                 'infrastructure.\n'
#                                 '\n'
#                                 '---\n'
#                                 '\n'
#                                 '#### Hurricane Ida\n'
#                                 '\n'
#                                 '**Storm Details:**\n'
#                                 '- **Storm Name:** Hurricane Ida\n'
#                                 '- **Category:** 4\n'
#                                 '- **Wind Speed:** 145 mph 💨\n'
#                                 '- **Coordinates:** Latitude: 25.5, Longitude: '
#                                 '-81.5\n'
#                                 '\n'
#                                 '**Impact Forecast:**\n'
#                                 'Hurricane Ida is a powerful Category 4 storm, '
#                                 'posing a significant threat due to its high '
#                                 'wind speeds. It is anticipated to make '
#                                 'landfall soon, affecting various regions, '
#                                 'specifically:\n'
#                                 '- **Affected Areas:** Florida, Georgia, South '
#                                 'Carolina 🌴🔴\n'
#                                 '\n'
#                                 '**Evacuation Orders:**\n'
#                                 'Authorities are issuing warnings for '
#                                 'evacuation orders in the anticipated impact '
#                                 'zones to ensure the safety of residents. '
#                                 'Specific evacuation procedures and routes '
#                                 'will be provided by local emergency '
#                                 'services.\n'
#                                 '\n'
#                                 '---\n'
#                                 '\n'
#                                 '#### Flooding in Southern Texas and '
#                                 'Louisiana\n'
#                                 '\n'
#                                 '**Flood Details:**\n'
#                                 '- **Flood Warning:** Active 🚨\n'
#                                 '- **Affected Regions:** Southern Texas, '
#                                 'Louisiana\n'
#                                 '\n'
#                                 '**Rainfall Data:**\n'
#                                 '- **24-hour Rainfall:** 10.5 inches 🌧️\n'
#                                 '- **Total Rainfall Over Last 72 Hours:** 30.1 '
#                                 'inches 📏\n'
#                                 '\n'
#                                 'Given the substantial rainfall, there is an '
#                                 'ongoing risk of severe flooding in affected '
#                                 'areas, necessitating immediate attention from '
#                                 'local disaster management teams.\n'
#                                 '\n'
#                                 '**River Levels:**\n'
#                                 '- **River:** Mississippi River\n'
#                                 '- **Current Level:** [Data not provided; '
#                                 'requires current status]\n'
#                                 '- **Flood Stage:** [Data not provided; '
#                                 'requires flood stage reference]\n'
#                                 '\n'
#                                 '**Forecast:**\n'
#                                 'The expected peak river level is projected to '
#                                 'reach **36.0 feet**, which demands urgent '
#                                 'response efforts and potential evacuation '
#                                 'orders. \n'
#                                 '\n'
#                                 '---\n'
#                                 '\n'
#                                 '#### Conclusion\n'
#                                 'The dual threats of Hurricane Ida and '
#                                 'flooding in Southern Texas and Louisiana '
#                                 'present a critical situation requiring swift '
#                                 'response and coordination among state and '
#                                 'federal agencies. Residents in the affected '
#                                 'areas are urged to stay informed through '
#                                 'local weather reports and follow the guidance '
#                                 'of emergency management officials to ensure '
#                                 'their safety. The combination of high winds '
#                                 'from the hurricane and unprecedented rainfall '
#                                 'leading to flooding underscores the need for '
#                                 'heightened preparedness and community support '
#                                 'in these challenging times. 🙏\n'
#                                 '\n'
#                                 '---\n'
#                                 '\n'
#                                 '#### Recommendations\n'
#                                 '1. **Regular Updates:** Establish a '
#                                 'communication system for real-time updates '
#                                 'regarding both climate phenomena.\n'
#                                 '2. **Evacuation Drills:** Conduct drills to '
#                                 'prepare residents in vulnerable regions for '
#                                 'potential evacuations.\n'
#                                 '3. **Flood Preparedness:** Equip communities '
#                                 'with resources for flood safety and recovery '
#                                 'efforts. 🛟\n'
#                                 '4. **Monitoring:** Ensure constant monitoring '
#                                 'of river levels and weather forecasts to '
#                                 'provide timely warnings. \n'
#                                 '\n'
#                                 'This report is essential for ensuring '
#                                 'community safety and preparedness during '
#                                 'these severe weather events. 🌍💙',
#                 'messages': [HumanMessage(content='Final report: **Final Weather Report on Flood and Hurricane** 🌪️🌧️\n\n### Report on Recent Natural Disasters: Hurricane Ida and Flooding in Southern Texas and Louisiana\n\n#### Overview\nThis report summarizes the current situation regarding Hurricane Ida and significant flooding incidents affecting Southern Texas and Louisiana. The data reflects the severity and potential impact of these natural disasters on nearby populations and infrastructure.\n\n---\n\n#### Hurricane Ida\n\n**Storm Details:**\n- **Storm Name:** Hurricane Ida\n- **Category:** 4\n- **Wind Speed:** 145 mph 💨\n- **Coordinates:** Latitude: 25.5, Longitude: -81.5\n\n**Impact Forecast:**\nHurricane Ida is a powerful Category 4 storm, posing a significant threat due to its high wind speeds. It is anticipated to make landfall soon, affecting various regions, specifically:\n- **Affected Areas:** Florida, Georgia, South Carolina 🌴🔴\n\n**Evacuation Orders:**\nAuthorities are issuing warnings for evacuation orders in the anticipated impact zones to ensure the safety of residents. Specific evacuation procedures and routes will be provided by local emergency services.\n\n---\n\n#### Flooding in Southern Texas and Louisiana\n\n**Flood Details:**\n- **Flood Warning:** Active 🚨\n- **Affected Regions:** Southern Texas, Louisiana\n\n**Rainfall Data:**\n- **24-hour Rainfall:** 10.5 inches 🌧️\n- **Total Rainfall Over Last 72 Hours:** 30.1 inches 📏\n\nGiven the substantial rainfall, there is an ongoing risk of severe flooding in affected areas, necessitating immediate attention from local disaster management teams.\n\n**River Levels:**\n- **River:** Mississippi River\n- **Current Level:** [Data not provided; requires current status]\n- **Flood Stage:** [Data not provided; requires flood stage reference]\n\n**Forecast:**\nThe expected peak river level is projected to reach **36.0 feet**, which demands urgent response efforts and potential evacuation orders. \n\n---\n\n#### Conclusion\nThe dual threats of Hurricane Ida and flooding in Southern Texas and Louisiana present a critical situation requiring swift response and coordination among state and federal agencies. Residents in the affected areas are urged to stay informed through local weather reports and follow the guidance of emergency management officials to ensure their safety. The combination of high winds from the hurricane and unprecedented rainfall leading to flooding underscores the need for heightened preparedness and community support in these challenging times. 🙏\n\n---\n\n#### Recommendations\n1. **Regular Updates:** Establish a communication system for real-time updates regarding both climate phenomena.\n2. **Evacuation Drills:** Conduct drills to prepare residents in vulnerable regions for potential evacuations.\n3. **Flood Preparedness:** Equip communities with resources for flood safety and recovery efforts. 🛟\n4. **Monitoring:** Ensure constant monitoring of river levels and weather forecasts to provide timely warnings. \n\nThis report is essential for ensuring community safety and preparedness during these severe weather events. 🌍💙', additional_kwargs={}, response_metadata={}, name='auctioneer', id='64c372f5-0af2-4e43-8194-ce1ce2263b4f')]}}
# '============================'

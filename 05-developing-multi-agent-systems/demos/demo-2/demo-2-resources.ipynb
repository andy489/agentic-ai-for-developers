# %% [markdown]
# # Module 2 — Resources & Links
# **Advanced Scenarios in Multi-agent Systems**

# %%
from IPython.display import HTML, display

def section(title, icon, links, accent='#7b2ff7'):
    items = ''.join(
        f'<li style="margin:8px 0">'
        f'<a href="{url}" target="_blank" style="color:{accent};text-decoration:none;font-size:14px">'
        f'<span style="margin-right:6px">&#x1F517;</span>{label}</a></li>'
        for label, url in links
    )
    display(HTML(f'''
    <div style="font-family:sans-serif;margin:16px 0;border-left:4px solid {accent};
                padding:12px 20px;background:#f8f0ff;border-radius:0 8px 8px 0">
      <h3 style="margin:0 0 10px;color:#4a0096;font-size:16px">{icon}&nbsp;{title}</h3>
      <ul style="list-style:none;margin:0;padding:0">{items}</ul>
    </div>
    '''))

display(HTML('''
<div style="font-family:sans-serif;background:linear-gradient(135deg,#4a0096,#7b2ff7);
            color:white;padding:28px 32px;border-radius:12px;margin-bottom:8px">
  <h1 style="margin:0 0 6px;font-size:26px">&#x1F916; Module 2 Resources</h1>
  <p style="margin:0;opacity:0.85;font-size:14px">Advanced Scenarios in Multi-agent Systems &mdash; Game Theory, Swarm &amp; Hierarchies</p>
</div>
'''))

section('LangGraph — Multi-agent Architectures', '&#x1F9F1;', [
    ('Multi-agent systems — LangGraph Concepts', 'https://langchain-ai.github.io/langgraph/concepts/multi_agent/'),
    ('Network Architecture', 'https://langchain-ai.github.io/langgraph/concepts/multi_agent/#network'),
    ('Hierarchical Agent Teams', 'https://langchain-ai.github.io/langgraph/tutorials/multi_agent/hierarchical_agent_teams/'),
    ('LangGraph Multi-Agent Workflows (Blog)', 'https://blog.langchain.dev/langgraph-multi-agent-workflows/'),
    ('LangGraph Multi-Agent Swarm', 'https://github.com/langchain-ai/langgraph-swarm-py'),
    ('LangGraph Multi-Agent Supervisor', 'https://github.com/langchain-ai/langgraph-supervisor-py'),
    ('Agents — LangSmith Evaluation Concepts', 'http://docs.smith.langchain.com/evaluation/concepts#agents'),
])

section('Game Theory', '&#x265F;', [
    ('Game Theory — Wikipedia', 'https://en.wikipedia.org/wiki/Game_theory'),
    ('Can LLMs Serve as Rational Players in Game Theory? (arXiv)', 'https://arxiv.org/pdf/2312.05488'),
    ('Game Theory Meets Large Language Models — Systematic Survey (arXiv)', 'https://arxiv.org/pdf/2502.09053'),
])

section('Swarm Intelligence & Agent Research', '&#x1F41D;', [
    ('Model Swarms: Collaborative Search to Adapt LLM Experts via Swarm Intelligence (arXiv)', 'https://arxiv.org/html/2410.11163v1'),
    ('Whitepaper Agent Companion', 'https://www.kaggle.com/whitepaper-agent-companion'),
])

section('Models', '&#x26A1;', [
    ('Introducing Claude 4', 'https://www.anthropic.com/news/claude-4'),
])
